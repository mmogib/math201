# %% [markdown]
# # 14.6 Directional Derivatives and the Gradient Vector
#
# __[Illustration](https://www.geogebra.org/m/Trws2PBm)__
#
# ![Directional Derovatove](./directional_derivative.png)
#
# ### Remarks
# 1. $D_{\bf i}f=f_x, D_{\bf j}f=f_y, $
#
# ![Theorem](./directional_derivative_theorem.png)
#
# ### Example
# Find the directional derivative $D_{\bf u}f(x,y)$ if
# $$
# f(x,y) = x^3-3xy+4y^2
# $$
# and $\bf u$ is the unit vector given by angle $\theta={\pi \over 6}$. What is $D_{\bf u}f(1,2)?$
#
# # The Gradient Vector
# ![Gradient Vector](./gradient_vector.png)
#
# ### Remark
# $$
# D_{\bf u} f(x,y)= \nabla f(x,y)\cdot {\bf u}
# $$
# ### Example
# Find the directional derivative of the function $f(x,y)=x^2y^3-4y$ at the point $(2,-1)$ in the direction of the vector ${\bf v}=2{\bf i}+5{\bf j}$.
# __SOLUTION IN CLASS__
#
# ## Functions of the Three Variables
#
# ![Directional Derivative in 3 variables](./directional_derivative_3d.png)
#
# ### Example
# If $f (x, y, z) = x \sin yz$,
#
# (a) find the gradient of $f$ and
#
# (b) find the directional derivative of $f$ at $(1, 3, 0)$ in the direction of ${\bf v} = i + 2 j – k$.
#
# ## Maximizing the Directional Derivative
# ![Maximizing the Directional Derivative](./directional_derivative_max.png)
#
# ### Example
# (a) If $f(x, y) = xe^y$, find the rate of change of $f$ at the point $P(2, 0)$ in the direction from $P$ to $Q({1 \over 2},2)$.
#
# (b) In what direction does $f$ have the maximum rate of change? What is this maximum rate of change?
#
#
# ## Tangent Planes to Level Surfaces
#
# Suppose $S$ is a surface with equation
# $$F(x, y, z) = k,$$
# that is, it is a level surface of a function $F$ of three variables, and let $P(x_0, y_0, z_0)$ be a point on $S$.
#
# Let $C$ be any curve that lies on the surface $S$ and passes through the point $P$. Recall that the curve $C$ is described by a continuous vector function
# $${\bf r}(t) = \langle x(t), y(t), z(t) \rangle$$.
#
# Let $t_0$ be the parameter value corresponding to $P$; that is, ${\bf r}(t_0) = \langle x0, y0, z0 \rangle$. Since $C$ lies on $S$, any point $(x(t), y(t), z(t))$ must satisfy the equation of $S$, that is,
#
# $$F(x(t), y(t), z(t)) = k, \qquad (*)$$
#
# If $x, y,$ and $z$ are differentiable functions of $t$ and $F$ is also differentiable, then we can use the Chain Rule to differentiate both sides of Equation (\*) as follows:
#
# $$
# \frac{\partial F}{\partial x} \frac{d x}{dt}+ \frac{\partial F}{\partial y} \frac{d y}{dt}+ \frac{\partial F}{\partial z} \frac{d z}{dt}=0 \qquad (**)
# $$
#
# But, since $\nabla F = \langle F_x, F_y, F_z\rangle$ and $r'(t) = \langle x'(t), y'(t), z'(t)\rangle$, Equation (\*\*) can be written in terms of a dot product as
#
#  $$ \nabla F \cdot  r'(t) = 0 $$
#
# In particular, when $t = t_0$ we have $r(t_0) = \langle x_0, y_0, z_0\rangle $, so
#
# $$ \nabla F(x_0, y_0, z_0) \cdot r'(t_0) = 0 $$
#
#
# This says that the gradient vector at $P$, $\nabla F(x_0, y_0, z_0)$, is perpendicular to the tangent vector $r'(t_0)$ to any curve $C$ on $S$ that passes through $P$.
#
# ![Tangent to Level Surfaces](./tangets_to_level_surfaces.png)
#
# If $\nabla F(x_0, y_0, z_0) = 0$, it is therefore natural to define __the tangent plane to the level surface__  $F(x, y, z) = k$ __at__ $P(x_0, y_0, z_0)$ as the plane that passes through $P$ and has normal vector $\nabla F(x_0, y_0, z_0)$.
#
# Using the standard equation of a plane, we can write the equation of this tangent plane as
#
# $$
# F_x(x_0,y_0,z_0)(x-x_0) + F_y(x_0,y_0,z_0)(y-y_0)+ F_z(x_0,y_0,z_0)(z-z_0)=0
# $$
#
# The normal line to $S$ at $P$ is the line passing through $P$ and perpendicular to the tangent plane.
#
# The direction of the normal line is therefore given by the gradient vector $\nabla F(x_0, y_0, z_0)$ and so, its symmetric equations are
#
# \\[
# \frac{x-x_0}{F_x(x_0,y_0,z_0)} = \frac{y-y_0}{F_y(x_0,y_0,z_0)} = \frac{z-z_0}{F_z(x_0,y_0,z_0)}
# \\]
#
# ## Example
# Find the equations of the tangent plane and normal line at the point $(–2, 1, –3)$ to the ellipsoid
# \\[
# \frac{x^2}{4}+y^2 + \frac{z^2}{9} = 3
# \\]
#
# ### Remark
# ![Tangent Level Curve](./tangets_to_level_curves.png)
