# %% [markdown]
# # 14.5 Chain Rule
#
# ![Chain Rule - Case 1](./chain_rule_1.png)
#
#
# ![Chain Rule - Case 1](./chain_rule_1-2.png)
#
#
# ### Example
# If $z = x^2y + 3xy^4$, where $x = \sin 2t$ and $y = \cos t$, find $dz/dt$ when $t = 0$.
#
#
# ![Chain Rule - Case 2](./chain_rule_2.png)
#
# ### Remark
# __Tree diagram__
# ![Chain Rule - Tree Diagram](./chain_rule_tree_1.png)
#
#
#
#
# ![Chain Rule - General Case](./chain_rule.png)
#
#
# ### Examples
# 1. Use the Chain Rule to find $\partial z/\partial s$ and $\partial z/\partial t$ where
# $$
# z=\tan^{-1}(x^2+y^2), \quad x=s\ln t, \quad y=te^s
# $$
# 2. Find $\partial P/\partial x$ and  $\partial P/\partial y$ when $x=0, y=2$ where
# $$
# P=\sqrt{u^2+v^2+w^2}, \quad u=xe^y,\quad v=ye^x, \quad w=e^{xy}
# $$
#
# ## Implicit Differentiation
# Let
# $$
# F (x, y) = 0
# $$
# where $y=f(x)$. Then
#
# $$
# \frac{\partial F}{\partial x}\frac{dx}{dx}  + \frac{\partial F}{\partial y} \frac{dy}{dx} =0
# $$
#
# Then
# $$
# \frac{dy}{dx} = - \frac{\frac{\partial F}{\partial x}}{\frac{\partial F}{\partial y}}=-\frac{F_x}{F_y}
# $$
#
# ### Example
# Find $y'$ where $x^3+y^3 =6xy$
#
# ## if $F(x,y,z)=0$
#
# ![Implicit Differentiation](./implicit_xyz.png)
#
# ### Example
# Find $\frac{\partial z}{\partial x}$ and $\frac{\partial z}{\partial y}$ if
# $$
# x^3+y^3+z^3+6xyz =1
# $$
